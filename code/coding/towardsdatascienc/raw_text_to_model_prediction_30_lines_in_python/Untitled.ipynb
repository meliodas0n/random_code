# %%
import numpy as np
from atom import ATOMClassifier
from sklearn.datasets import fetch_20newsgroups

# %%
X, y = fetch_20newsgroups(return_X_y = True, categories = ['alt.atheism', 'sci.med', 'comp.windows.x', 'misc.forsale', 'sci.electronics',],)

# %%
X = np.array(X).reshape(-1, 1)

# %%
atom = ATOMClassifier(X, y, test_size = 0.2, verbose = 2)
# Out:
# << ================== ATOM ================== >>
# Algorithm task: multiclass classification.
#
# Dataset stats ==================== >>
# Shape: (2843, 2)
# Memory: 5.08 MB
# Scaled: False
# Categorical features: 1 (100.0%)
# -------------------------------------
# Train set size: 2275
# Test set size: 568
# -------------------------------------
# |   |     dataset |       train |        test |
# | - | ----------- | ----------- | ----------- |
# | 0 |   480 (1.0) |   384 (1.0) |    96 (1.0) |
# | 1 |   593 (1.2) |   475 (1.2) |   118 (1.2) |
# | 2 |   585 (1.2) |   468 (1.2) |   117 (1.2) |
# | 3 |   591 (1.2) |   473 (1.2) |   118 (1.2) |
# | 4 |   594 (1.2) |   475 (1.2) |   119 (1.2) |

# %%
atom.dataset
# Out:
#                                                  corpus  target
# 0     From: keith@cco.caltech.edu (Keith Allan Schne...       0
# 1     From: reidg@pacs.pha.pa.us ( Reid Goldsborough...       2
# 2     From: perry@dsinc.com (Jim Perry)\nSubject: Re...       0
# 3     From: ibeshir@nyx.cs.du.edu (Ibrahim)\nSubject...       2
# 4     From: mahan@TGV.COM (Patrick L. Mahan)\nSubjec...       1
# ...                                                 ...     ...
# 2838  From: rivkin@watson.bms.com (TERRI RIVKIN, TER...       2
# 2839  From: blakey@ug.cs.dal.ca (Jason Blakey)\nSubj...       3
# 2840  Subject: 68HC16 public domain software?\nFrom:...       3
# 2841  From: jfare@53iss6.Waterloo.NCR.COM (Jim Fare)...       4
# 2842  From: mathew <mathew@mantis.co.uk>\nSubject: R...       0
#
# [2843 rows x 2 columns]

# %%
atom.corpus[0]
# Out:
# "From: keith@cco.caltech.edu (Keith Allan Schneider)\nSubject: Re: <Political Atheists?\nOrganization: California Institute of Technology, Pasadena\nLines: 14\nNNTP-Posting-Host: lloyd.caltech.edu\n\nbobbe@vice.ICO.TEK.COM (Robert Beauchaine) writes:\n\n>To show that the examples I and others\n>have provided are *not* counter examples of your supposed inherent\n>moral hypothesis, you have to successfully argue that\n>domestication removes or alters this morality.\n\nI think that domestication will change behavior to a large degree.\nDomesticated animals exhibit behaviors not found in the wild.  I\ndon't think that they can be viewed as good representatives of the\nwild animal kingdom, since they have been bred for thousands of years\nto produce certain behaviors, etc.\n\nkeith\n"

# %%
atom.textclean()
# Out:
# Cleaning the corpus...
#  --> Decoding unicode characters to ascii.
#  --> Converting text to lower case.
#  --> Dropping 9728 emails from 2829 documents.
#  --> Dropping 0 URL links from 0 documents.
#  --> Dropping 2080 HTML tags from 1230 documents.
#  --> Dropping 3 emojis from 3 documents.
#  --> Dropping 31748 numbers from 2840 documents.
#  --> Dropping punctuation from the text.

# %%
atom.drops
# Out:
#                                                   email  url      html emoji  \
# 0       [keith@cco.caltech.edu, bobbe@vice.ico.tek.com]  NaN       NaN   NaN
# 1          [reidg@pacs.pha.pa.us, reidg@pacs.pha.pa.us]  NaN       NaN   NaN
# 2     [perry@dsinc.com, 114133@bu.edu, jaeger@buphy....  NaN  [<>, <>]   NaN
# 3                               [ibeshir@nyx.cs.du.edu]  NaN       NaN   NaN
# 4     [mahan@tgv.com, xpert@expo.lcs.mit.edu, dyoung...  NaN       NaN   NaN
# ...                                                 ...  ...       ...   ...
# 1376                                                NaN  NaN       NaN   NaN
# 1627                                                NaN  NaN       NaN   NaN
# 1950                                                NaN  NaN       NaN   NaN
# 2734                                                NaN  NaN       NaN   NaN
# 2802                                                NaN  NaN       NaN   NaN
#
#                                                  number
# 0                                                  [14]
# 1     [60, 5, 99, 45, 5, 99, 45, 2, 0, 119, 45, 4, 0...
# 2                                [80, 1989, 1990, 1985]
# 3                                     [5, 1200, 101, 0]
# 4                                            [51, 8, 1]
# ...                                                 ...
# 1376  [27, 15, 27, 225, 250, 412, 624, 6115, 371, 0154]
# 1627  [13, 93, 212, 274, 0646, 1097, 08836, 908, 563...
# 1950                                    [8051, 3, 8051]
# 2734                          [47, 252, 4, 179, 34, 12]
# 2802                                         [15, 1, 1]
#
# [2843 rows x 5 columns]

# %%
atom.corpus[0]
# Out:
# 'from  keith allan schneider\nsubject re political atheists\norganization california institute of technology pasadena\nlines \nnntppostinghost lloydcaltechedu\n\n robert beauchaine writes\n\nto show that the examples i and others\nhave provided are not counter examples of your supposed inherent\nmoral hypothesis you have to successfully argue that\ndomestication removes or alters this morality\n\ni think that domestication will change behavior to a large degree\ndomesticated animals exhibit behaviors not found in the wild  i\ndont think that they can be viewed as good representatives of the\nwild animal kingdom since they have been bred for thousands of years\nto produce certain behaviors etc\n\nkeith\n'

# %%
atom.tokenize()
# Out:
# Tokenizing the corpus...
# [nltk_data] Downloading package punkt to /home/meliodas/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
atom.corpus[0][:7]
# Out:
# ['from', 'keith', 'allan', 'schneider', 'subject', 're', 'political']

# %%
atom.plot_wordcloud()

# %%
atom.normalize(stopwords = "english", lemmatize = True)
# Out:
# Normalizing the corpus...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/meliodas/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#  --> Dropping stopwords.
# [nltk_data] Downloading package wordnet to /home/meliodas/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/meliodas/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package omw-1.4 to /home/meliodas/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
#  --> Applying lemmatization.

# %%
atom.corpus[0][:7]
# Out:
# ['keith',
#  'allan',
#  'schneider',
#  'subject',
#  'political',
#  'atheist',
#  'organization']

# %%
atom.plot_ngrams(ngram = 2)

# %%
atom.tokenize(bigram_freq = 200)
# Out:
# Tokenizing the corpus...
#  --> Creating 9 bigrams on 3901 locations.

# %%
print(atom)
# Out:
# ATOMClassifier
#  --> Branches: master
#  --> Models: None
#  --> Metric: None
#  --> Errors: 0

# %%
atom.vectorize(strategy = "tfidf")
# Out:
# Fitting Vectorizer...
# Vectorizing the corpus...

# %%
atom.shape
# Out:
# (2843, 30216)

# %%
atom.display
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.109101
#           ...
# 2838    0.000000
# 2839    0.000000
# 2840    0.000000
# 2841    0.000000
# 2842    0.000000
# Name: display, Length: 2843, dtype: Sparse[float64, 0]

# %%
atom.dataset.dtypes
# Out:
# 00          Sparse[float64, 0]
# 000         Sparse[float64, 0]
# 000000e5    Sparse[float64, 0]
# 00000ee5    Sparse[float64, 0]
# 000010af    Sparse[float64, 0]
#                    ...
# zurich      Sparse[float64, 0]
# zurlo       Sparse[float64, 0]
# zvi         Sparse[float64, 0]
# zyklonb     Sparse[float64, 0]
# target                   int64
# Length: 30216, dtype: object

# %%
atom.available_models()
# Out:
#    acronym                         fullname                       estimator  \
# 0    Dummy                  Dummy Estimator                 DummyClassifier
# 1       GP                 Gaussian Process       GaussianProcessClassifier
# 2      GNB             Gaussian Naive Bayes                      GaussianNB
# 3      MNB          Multinomial Naive Bayes                   MultinomialNB
# 4      BNB            Bernoulli Naive Bayes                     BernoulliNB
# 5    CatNB          Categorical Naive Bayes                   CategoricalNB
# 6      CNB           Complement Naive Bayes                    ComplementNB
# 7    Ridge                  Ridge Estimator                 RidgeClassifier
# 8     Perc                       Perceptron                      Perceptron
# 9       LR              Logistic Regression              LogisticRegression
# 10     LDA     Linear Discriminant Analysis      LinearDiscriminantAnalysis
# 11     QDA  Quadratic Discriminant Analysis   QuadraticDiscriminantAnalysis
# 12     KNN              K-Nearest Neighbors            KNeighborsClassifier
# 13     RNN         Radius Nearest Neighbors       RadiusNeighborsClassifier
# 14    Tree                    Decision Tree          DecisionTreeClassifier
# 15     Bag                          Bagging               BaggingClassifier
# 16      ET                      Extra-Trees            ExtraTreesClassifier
# 17      RF                    Random Forest          RandomForestClassifier
# 18    AdaB                         AdaBoost              AdaBoostClassifier
# 19     GBM        Gradient Boosting Machine      GradientBoostingClassifier
# 20    hGBM                          HistGBM  HistGradientBoostingClassifier
# 21     XGB                          XGBoost                   XGBClassifier
# 22     LGB                         LightGBM                  LGBMClassifier
# 23    CatB                         CatBoost              CatBoostClassifier
# 24    lSVM                       Linear SVM                       LinearSVC
# 25    kSVM                       Kernel SVM                             SVC
# 26      PA               Passive Aggressive     PassiveAggressiveClassifier
# 27     SGD      Stochastic Gradient Descent                   SGDClassifier
# 28     MLP           Multi-layer Perceptron                   MLPClassifier
#
#                                                module needs_scaling  \
# 0                                       sklearn.dummy         False
# 1                       sklearn.gaussian_process._gpc         False
# 2                                 sklearn.naive_bayes         False
# 3                                 sklearn.naive_bayes         False
# 4                                 sklearn.naive_bayes         False
# 5                                 sklearn.naive_bayes         False
# 6                                 sklearn.naive_bayes         False
# 7                         sklearn.linear_model._ridge          True
# 8                    sklearn.linear_model._perceptron          True
# 9                      sklearn.linear_model._logistic          True
# 10                      sklearn.discriminant_analysis         False
# 11                      sklearn.discriminant_analysis         False
# 12                  sklearn.neighbors._classification          True
# 13                  sklearn.neighbors._classification          True
# 14                              sklearn.tree._classes         False
# 15                          sklearn.ensemble._bagging         False
# 16                           sklearn.ensemble._forest         False
# 17                           sklearn.ensemble._forest         False
# 18                  sklearn.ensemble._weight_boosting         False
# 19                               sklearn.ensemble._gb         False
# 20  sklearn.ensemble._hist_gradient_boosting.gradi...         False
# 21                                    xgboost.sklearn          True
# 22                                   lightgbm.sklearn          True
# 23                                      catboost.core          True
# 24                               sklearn.svm._classes          True
# 25                               sklearn.svm._classes          True
# 26           sklearn.linear_model._passive_aggressive          True
# 27          sklearn.linear_model._stochastic_gradient          True
# 28      sklearn.neural_network._multilayer_perceptron          True
#
#    accepts_sparse supports_gpu
# 0           False        False
# 1           False        False
# 2           False         True
# 3            True         True
# 4            True         True
# 5            True         True
# 6            True        False
# 7            True         True
# 8           False        False
# 9            True         True
# 10          False        False
# 11          False        False
# 12           True         True
# 13           True        False
# 14           True        False
# 15           True        False
# 16           True        False
# 17           True         True
# 18           True        False
# 19           True        False
# 20          False        False
# 21           True         True
# 22           True         True
# 23           True         True
# 24           True         True
# 25           True         True
# 26           True        False
# 27           True        False
# 28           True        False

# %%
atom.run(models = 'RF', metric = "f1_weighted")
# Out:
# Training ========================= >>
# Models: RF
# Metric: f1_weighted
#
#
# Results for Random Forest:
# Fit ---------------------------------------------
# Train evaluation --> f1_weighted: 1.0
# Test evaluation --> f1_weighted: 0.9312
# Time elapsed: 25.047s
# -------------------------------------------------
# Total time: 25.047s
#
#
# Final results ==================== >>
# Duration: 25.048s
# -------------------------------------
# Random Forest --> f1_weighted: 0.9312

# %%
atom.evaluate()
# Out:
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#     balanced_accuracy  f1_weighted  jaccard_weighted  matthews_corrcoef  \
# RF           0.932486     0.931191          0.872485           0.914438
#
#     precision_weighted  recall_weighted
# RF            0.932703         0.931338

# %%
atom.plot_confusion_matrix()
# Out:
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.

# %%
atom.decision_plot(index = 0, target = atom.predict(0), show = 10)
# Out:
# `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
